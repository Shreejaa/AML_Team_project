# %% [markdown]
# ### Raw Data Analysis

# %%
import matplotlib.pyplot as plt
from pydicom import dcmread
from pydicom.data import get_testdata_file

flair_ds = dcmread('Image-114.dcm')
plt.imshow(flair_ds.pixel_array, cmap=plt.cm.gray)
plt.show()

# %%
flair_ds = dcmread('1.dcm')
plt.imshow(flair_ds.pixel_array, cmap=plt.cm.gray)
plt.show()

# %%
flair_ds = dcmread('Image-36.dcm')
plt.imshow(flair_ds.pixel_array, cmap=plt.cm.gray)
plt.show()

# %%
flair_ds = dcmread('Image-108.dcm')
plt.imshow(flair_ds.pixel_array, cmap=plt.cm.gray)
plt.show()
